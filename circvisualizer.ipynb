# %%
import sys
import pyzx
sys.path.append('.')  # Adds the current folder to the path

from altfloquetcolour import AltFloquetColour
from IPython.display import SVG

# Create the circuit
mycol = AltFloquetColour(graph=None, Lx=2, Ly=2) 
circ = mycol.stimCircuit()

# Convert to SVG
svg_diagram = str(circ.diagram("timeline-svg"))

# Display SVG
SVG(svg_diagram)
# Out:
# Circuit generated with 68 X measurements 32 Z measurements 16 Hadamards.

# %%
# !pip install pyzx
# Out:
# ...
#   Using cached pyzx-0.9.0-py3-none-any.whl.metadata (6.1 kB)
# ...
#   Using cached pyperclip-1.9.0.tar.gz (20 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Using cached ipywidgets-8.1.7-py3-none-any.whl.metadata (2.4 kB)
# ...
#   Using cached lark-1.2.2-py3-none-any.whl.metadata (1.8 kB)
# ...
#   Using cached widgetsnbextension-4.0.14-py3-none-any.whl.metadata (1.6 kB)
# ...
#   Using cached jupyterlab_widgets-3.0.15-py3-none-any.whl.metadata (20 kB)
# ...
# Using cached pyzx-0.9.0-py3-none-any.whl (358 kB)
# Using cached ipywidgets-8.1.7-py3-none-any.whl (139 kB)
# Using cached jupyterlab_widgets-3.0.15-py3-none-any.whl (216 kB)
# Using cached widgetsnbextension-4.0.14-py3-none-any.whl (2.2 MB)
# Using cached lark-1.2.2-py3-none-any.whl (111 kB)
# ...
#   Created wheel for pyperclip: filename=pyperclip-1.9.0-py3-none-any.whl size=11117 sha256=5aa77be1f6aa8e9a67a9dd1721764390949567c8a017d17d383768d9ef79cb81
# ...
